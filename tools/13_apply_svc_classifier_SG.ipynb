# %% [markdown]
# ## Grab a list of XML files to run through the classifier

# %%
import glob

files_to_classify = [p for p in sorted(glob.glob('/home/seth/Notes/HDW/textbase/xml/*.xml')) \
                   if '_clean' not in p]

print(len(files_to_classify))
# Out:
# 200

# %% [markdown]
# ## Are any of the XML files not well-formed?

# %%
from lxml import etree

valid_input_files = []
broken_xml_files = []

for p in files_to_classify:
    try:
        tree = etree.parse(p)
        valid_input_files.append(p)
    except etree.XMLSyntaxError:
        broken_xml_files.append(p)
        
print('len(valid_input_files)', len(valid_input_files),
     'len(broken_xml_files)', len(broken_xml_files))

print()
for p in broken_xml_files:
    print('BROKEN?', p)
# Out:
# len(valid_input_files) 200 len(broken_xml_files) 0

# %% [markdown]
# ## Load the classifier and dictionary  . . .
#
#  . . . from 12_make_svc_classifier_SG.ipynb.

# %%
import pickle, re
from gensim import corpora, matutils
from sklearn.naive_bayes import *
from sklearn.ensemble import *

filename = 'SVC.saved_classifier.sav'
classifier = pickle.load(open(filename, 'rb'))

dictionary = corpora.Dictionary.load('SVC.classifier_dictionary.dict')

words_in_classifier = set(list(dictionary.values()))

print('len(words_in_classifier)', len(words_in_classifier))
print(words_in_classifier)  #just checking
# Out:
# len(words_in_classifier) 50714
# {'raretés', 'neve', 'vigilant', 'brocanteurs', 'complétaient', 'rougissante', 'enfa', 'palu', 'habilleuse', 'aéronaute', 'deläcombe', 'run', 'rayonné', 'osaient', 'sale', 'présider', 'ciselure', 'mobpital', 'accueillies', 'sangle', 'anxieux', 'treilles', 'entrainé', 'ésprit', 'rôder', 'religieusement', 'jaigoantà', 'approxima', 'cuapirre', 'leursavénements', 'effacent', 'jugeämes', 'cosmaceti', 'méconnaitre', 'absorbée', 'vanves', 'religeuse', 'aristocratie', 'conunise', 'maisonnêtte', 'ærvers', 'fouéde', 'boufflers', 'enfanta', 'flandre', 'local', 'ignoble', 'miasmes', 'nee', 'attaqués', 'assemblée', 'bâtissait', 'cilait', 'presqué', 'cirées', 'hostilités', 'souv', 'bliquel', 'égarer', 'narration', 'anneau', 'x1le', 'tonneau', 'possédaient', 'pollalion', '4re', 'bornerait', 'priseurs', 'abrêgé', 'princesse', 'türe', 'invendues', 'ency', 'enfants', 'tenaien', 'détfuire', 'nile', 'doré', 'fondit', 'estocard', 'slatues', 'parquée', 'muraille', 'institution', 'fuite', 'géométral', 'cipal', 'éeetie', 'monge', 'caractéris', 'gna', 'leuko', 'chchy', 'rambuteau', 'oil', 'famille', 'remarquerà', 'mode', 'ciselées', 'indiquons', 'dée', 'marchez', 'mendiants', 'supportant', 'contemporain', 'prud', 'riz', 'rest', 'buteau', 'promenait', 'dotre', 'submergée', 'ensevelis', 'peines', 'pécheurs', 'scénes', 'enfileur', 'loison', 'néron', 'veillance', 'élançaient', 'phidias', 'mmd', 'étourderie', 'gémi', 'professer', 'arriv', 'hémon', 'révélé', 'compagnes', 'mentionner', 'malignement', 'sévignés', 'itre', 'parfum', 'adeptes', 'vendredi', 'repoussées', 'moga', 'pondit', 'produisent', 'hæe', 'vauguyon', 'dudivisions', 'voulus', 'ravignan', 'êtres', 'hareng', 'résultai', 'chef', 'gîte', 'séduisantes', 'atteindrait', 'espôir', 'chatte', 'embarqué', 'combustibles', 'arttoutd', 'ruban', 'vaincue', 'heure', 'montrer', 'unetombe', 'protestantisme', 'gante', 'conque', 'déja', 'gravés', 'gazouillement', 'criaient', 'cierc', 'oekholm', 'officiers', 'quandies', 'dandinant', 'économies', 'immobiliser', 'montaigu', 'royaliste', 'bahut', 'infecte', 'girardon', 'ombragées', 'nalionale', 'mezières', 'abordables', 'stantoine', 'syncope', 'fidéles', 'act', 'recrues', 'profanes', 'lée', 'débarrasseraient', 'attendis', 'glossaire', 'suffisaient', 'convergeront', 'vengeances', 'lionne', 'nseille', 'monieux', 'embrassait', 'versé', 'importants', 'treptiles', 'ci', 'remplaça', 'tuons', 'formés', 'tiges', 'collage', 'pitti', 'csi', 'nourriciere', 'aveuglément', 'profita', 'rennelagh', 'oi', 'attroupées', 'cirque', 'poumons', 'che', 'gouz', 'espace', 'fôut', 'imdique', 'etudes', 'pressée', 'fécon', 'vallet', 'eperon', 'arte', 'quadrilatère', 'lutionnaire', 'menuisée', 'vousletrouvez', 'liant', 'kalbreuner', 'embranchement', 'induit', 'bourgnignons', 'déguise', 'passeront', 'dégager', 'concession', 'défendront', 'xo', 'értillerie', 'particulierement', 'certains', 'célibat', 'suaiterrorem', 'adaptée', 'valencieunes', 'rugit', 'geinte', 'grièvement', 'transféré', 'sanglot', 'chèle', 'breuillé', 'idéales', 'opposés', 'réserverait', 'rassemblée', 'assista', 'destruction', 'vépres', 'conservait', 'semée', 'mania', 'généralement', 'thrace', 'écleclisme', 'présentement', 'large', 'appropria', 'arhoré', 'épargnait', 'étouffé', 'relipieux', 'agités', 'croient', 'tasiant', 'tirétaine', 'butréligieux', 'blâämons', 'infirmité', 'suspendu', 'tradition', 'banva', 'cesimpressions', 'maive', 'èt', 'indissoluble', 'lalme', 'pares', 'michiels', 'crâ', 'inséra', 'suppliants', 'chanteuse', 'ramassé', 'namrnnnannnas', 'acquer', 'badatids', 'criarde', 'fonction', 'dope', 'sautaient', 'renfort', 'éculées', 'régnant', 'recommencé', 'traînant', 'cimet', 'chenal', 'descendriez', 'hâtai', 'sourciller', 'adhérents', 'esprit', 'murant', 'misère', 'consa', 's4g', 'croyions', 'ormeauxs', 'abuset', 'vôtre', 'combaltre', 'dômes', 'galloromaine', 'baignait', 'pompeusement', 'errements', 'recueillent', 'révélait', 'franefort', 'anticipé', 'captif', 'démesuré', 'nudveal', 'dédièxeb', 'minette', 'l1', 'dres ...

# %% [markdown]
# ## Process the XML files

# %%
grand_total_snippets = 0
grand_total_good_snippets = 0

for p in valid_input_files:
    
    tree = etree.parse(p)
    
    n_total_snippets = len(tree.xpath('//snippet'))
    n_good_snippets = 0
    
    matches_and_snippets = etree.Element('matches_and_snippets')
    
    for match in tree.xpath('//match'):
    
        snippet = match.xpath('descendant::snippet')[0]
        #get rid of extra space artefacts from OCR
        clean_text = re.sub(r'[^\s0123456789abcdefghijklmnopqrstuvwxyzàâäæçèéêëîïñôùûüÿœ̀]',
                           ' ',
                           snippet.text.lower())
        clean_text = re.sub('\s+', ' ', clean_text)
        #tokenize, but using only words previously determined to be meaningful
        tokens = [t for t in clean_text.split(' ') if t > '' and t in words_in_classifier]

        corpus = [dictionary.doc2bow(tokens),]

        matrix = matutils.corpus2dense(corpus, len(dictionary))
        matrix = matrix.T

        result = classifier.predict(matrix)[0]

        if result == 'good':
            n_good_snippets += 1
        
        snippet.set('classifier_result', result)
        matches_and_snippets.append(match)
        
            
    base_xml_name = p.split('/')[-1]
    
    print(base_xml_name.ljust(45), 
          'n_total_snippets', n_total_snippets, 
          '     n_good_snippets', n_good_snippets)
    
    #if n_good_snippets > 0: #Commented out so as to add match regardless of whether good.
        
    new_tree = etree.ElementTree(matches_and_snippets)
        
    new_tree.write('SVC.test_results_xml/' + base_xml_name, encoding='utf-8')
        
    grand_total_snippets += n_total_snippets
    grand_total_good_snippets += n_good_snippets
    
print()
print('grand_total_snippets', grand_total_snippets,
     '    grand_total_good_snippets', grand_total_good_snippets)
# Out:
# About_1861_bpt6k64392756.xml                  n_total_snippets 3      n_good_snippets 0
# Abrantès_1844_bpt6k6472523f.xml              n_total_snippets 16      n_good_snippets 0
# Achard_1860_bpt6k113880g.xml                  n_total_snippets 35      n_good_snippets 0
# Allix_1830_bpt6k6471452h.xml                  n_total_snippets 15      n_good_snippets 0
# Amigues_1871_bpt6k54697084.xml                n_total_snippets 2      n_good_snippets 0
# André_1874_bpt6k6112273x.xml                 n_total_snippets 4      n_good_snippets 0
# Arènes_de_Paris_1870_bpt6k1413153t.xml       n_total_snippets 26      n_good_snippets 0
# Asti_1843_bpt6k6471672z.xml                   n_total_snippets 28      n_good_snippets 8
# Auberive_1860_bpt6k6394066d.xml               n_total_snippets 175      n_good_snippets 57
# Avenir_de_Paris_1871_bpt6k5459219x.xml        n_total_snippets 2      n_good_snippets 0
# Balleydier_1849_bpt6k105490w.xml              n_total_snippets 136      n_good_snippets 33
# Balzac_1841_bpt6k1133819.xml                  n_total_snippets 11      n_good_snippets 0
# Bamboches_amoureuses_1840_bpt6k1164416j.xml   n_total_snippets 13      n_good_snippets 0
# Banville_1857_bpt6k6447544b.xml               n_total_snippets 4      n_good_snippets 0
# Banville_1866_bpt6k205836j.xml                n_total_snippets 44      n_good_snippets 0
# Barrault_1830_bpt6k85585d.xml                 n_total_snippets 1      n_good_snippets 0
# Bast_1841_bpt6k5672974d.xml                   n_total_snippets 75      n_good_snippets 0
# Becker_1837_bpt6k105479m.xml                  n_total_snippets 48      n_good_snippets 0
# Bellet_1857_bpt6k6456840p.xml                 n_total_snippets 2      n_good_snippets 0
# Berthet_1848_bpt6k6467497p.xml                n_total_snippets 2      n_good_snippets 0
# Berville_1857_bpt6k55254970.xml               n_total_snippets 1      n_good_snippets 0
# Bessière_1857_bpt6k55328205.xml              n_total_snippets 3      n_good_snippets 0
# Bigle_1870_bpt6k6524222g.xml                  n_total_snippets 5      n_good_snippets 0
# Bonnardot_1856_bpt6k6519741t.xml              n_total_snippets 582      n_good_snippets 9
# Bonneville_1830_bpt6k5530903c.xml             n_total_snippets 7      n_good_snippets 2
# Bonneville_1832_bpt6k6203416v.xml             n_total_snippets 16      n_good_snippets 0
# BorrellideSerres_1851_bpt6k835163.xml         n_total_snippets 6      n_good_snippets 0
# Bracevich_1842_bpt6k6378597c.xml              n_total_snippets 33      n_good_snippets 0
# Bréauté_1845_bpt6k64714083.xml              n_total_snippets 32      n_good_snippets 0
# Brunet_1871_bpt6k5453254h.xml                 n_total_snippets 4      n_good_snippets 0
# Caffind'Orsigny_1856_bpt6k859453d.xml         n_total_snippets 4      n_good_snippets 0
# Calliat_1850_bpt6k96678085.xml                n_total_snippets 11      n_good_snippets 0
# Cavaignac_1848_bpt6k24241g.xml                n_total_snippets 73      n_good_snippets 0
# Chaix_1854_bpt6k30569213.xml                  n_total_snippets 821      n_good_snippets 30
# Champagne_1871_bpt6k57891839.xml              n_total_snippets 4      n_good_snippets 0
# Champollion-Figeac_1833_bpt6k1249466.xml      n_total_snippets 50      n_good_snippets 0
# Chapus_1854_bpt6k6580447d.xml                 n_total_snippets 64      n_good_snippets 0
# Charpentier_1832_bpt6k1265557c.xml            n_total_snippets 9      n_good_snippets 0
# Chevalier_1838_bpt6k85819f.xml                n_total_snippets 3      n_good_snippets 0
# Chevallier_1834_bpt6k5786715m.xml             n_total_snippets 2      n_good_snippets 0
# Choumara__1833_bpt6k9785261n.xml              n_total_snippets 2      n_good_snippets 0
# Clark_1854_bpt6k5449597w.xml                  n_total_snippets 2      n_good_snippets 0
# Claudin_1862_bpt6k2000885.xml                 n_total_snippets 75      n_good_snippets 0
# Compte_régler_1871_bpt6k54484747.xml         n_total_snippets 2      n_good_snippets 0
# Concerts_1874_bpt6k5797100p.xml               n_total_snippets 130      n_good_snippets 0
# Cousin_Avallon_1834_bpt6k64291819.xml         n_total_snippets 38      n_good_snippets 4
# Cramouzaud_1855_bpt6k65447250.xml             n_total_snippets 144      n_good_snippets 0
# Daly_1872_bpt6k9781154x.xml                   n_total_snippets 1      n_good_snippets 0
# Daly_1880_bpt6k14181964.xml                   n_total_snippets 4      n_good_snippets 0
# De_la_localité_convenable_1832_bpt6k9692789j.xml n_total_snippets 6      n_good_snippets 0
# Delord_1854_bpt6k107871c.xml                  n_total_snippets 4      n_good_snippets 0
# Delvau_1863_bpt6k1522335s.xml                 n_total_snippets 126      n_good_snippets 0
# Denis_1871_bpt6k5551811f.xml                  n_total_snippets 39      n_good_snippets 0
# DesEssarts_1857_bpt6k113928r.xml              n_total_snippets 12      n_good_snippets 0
# Diable_Paris_1857_bpt6k63940561.xml           n_total_snippets 83      n_good_snippets 3
# DuBoys_1871_bpt6k61168522.xml                 n_total_snippets 11      n_good_snippets 0
# Dulaure_1846_bpt6k6374320w.xml                n_total_snippets 1305      n_good_snippets 27
# Dumas_1833_bpt6k55430949.xml                  n_total_snippets 2      n_good_snippets 0
# Durand_1871_bpt6k5807690k.xml                 n_total_snippets 1      n_good_snippets 0
# Duverdy_1877_bpt6k5783609m.xml                n_total_snippets 2      n_good_snippets 0
# Désarbres_1865_bpt6k6477725h.xml              n_total_snippets 28      n_good_snippets 0
# Edme_1871_bpt6k6549886k.xml                   n_total_snippets 8      n_good_snippets 0
# Eglises_et_monastères_1856_bpt6k64714120.xml n_total_snippets 137      n_good_snippets 0
# Embellissemens_Concorde_1839_bpt6k6378044h.xml n_total_snippets 7      n_good_snippets 0
# Faucon_1855_bpt6k54105303.xml                 n_total_snippets 687      n_good_snippets 13
# Ferrière_1838_bpt6k64357926.xml              n_total_snippets 655      n_good_snippets 18
# Féval_1845_bpt6k8630098m.xml                 n_total_snippets 27      n_good_snippets 0
# Févelat_1873_bpt6k6121068w.xml               n_total_snippets 4      n_good_snippets 0
# Fortifications_de_Paris_1833_bpt6k5540840k.xml n_total_snippets 43      n_good_snippets 0
# Fou_de_Paris_1842_bpt6k6121646c.xml           n_total_snippets 10      n_good_snippets 0
# Fougasse_1856_bpt6k61291553.xml               n_total_snippets 3      n_good_snippets 0
# Fourcade-Prunet_1862_bpt6k11750212.xml        n_total_snippets 21      n_good_snippets 0
# Fournel_1865_bpt6k1018901.xml                 n_total_snippets 269      n_good_snippets 0
# Fournel_1867_bpt6k757298.xml                  n_total_snippets 77      n_good_snippets 0
# Fournier_1860_bpt6k6416873z.xml               n_total_snippets 182      n_good_snippets 0
# François_1857_bpt6k6439790m.xml              n_total_snippets 403      n_good_snippets 69
# Frébault_1878_bpt6k6417456c.xml              n_total_snippets 172      n_good_snippets 0
# Gasparin_1845_bpt6k6465731b.xml               n_total_snippets 4      n_good_snippets 0
# Gasparin_1846_bpt6k755182.xml                 n_total_snippets 2      n_good_snippets 0
# Girault_1838_bpt6k5726164c.xml                n_total_snippets 457      n_good_snippets 32
# Gozlan_1852_bpt6k6439792f.xml                 n_total_snippets 4      n_good_snippets 0
# Grandeffe_1879_bpt6k5436685t.xml              n_total_snippets 73      n_good_snippets 1
# Grandmougin_1880_bpt6k6151389x.xml            n_total_snippets 1      n_good_snippets 0
# Guérin_1833_bpt6k8630655x.xml                n_total_snippets 52      n_good_snippets 0
# Guide_1855_bpt6k134268q.xml                   n_total_snippets 381      n_good_snippets 30
# Guide_commercial_Bercy_1854_bpt6k944478k.xml  n_total_snippets 60      n_good_snippets 0
# Guide_général_1855_bpt6k63783115.xml          n_total_snippets 381      n_good_snippets 30
# Guide_monde_élégant_1859_bpt6k35378j.xml    n_total_snippets 44      n_good_snippets 0
# Guide_monde_élégant_1859_bpt6k35378j.xml      n_total_snippets 44      n_good_snippets 0
# Guide_voyageur_1858_bpt6k35366j.xml           n_total_snippets 55      n_good_snippets 0
# Guillemin_1852_bpt6k5442829x.xml              n_total_snippets 1      n_good_snippets 0
# Guillon_1831_bpt6k5534250v.xml                n_total_snippets 7      n_good_snippets 0
# Hayet_1839_bpt6k6128692s.xml                  n_total_snippets 10      n_good_snippets 0
# Hugo_1831_1_bpt6k6497134z.xml                 n_total_snippets 149      n_good_snippets 66
# Hugo_1831_2_bpt6k6497803t.xml                 n_total_snippets 123      n_good_snippets 2
# Hugo_1858_bpt6k406195r.xml                    n_total_snippets 170      n_good_snippets 59
# Hugo_1867_bpt6k6439743z.xml                   n_total_snippets 43      n_good_snippets 0
# Husson_1873_bpt6k5819785h.xml                 n_total_snippets 1      n_good_snippets 0
# Indicateur_officiel_1858_bpt6k5481667q.xml    n_total_snippets 61      n_good_snippets 0
# Janin_1843_bpt6k102791c.xml                   n_total_snippets 163      n_good_snippets 0
# Jeandel_1854_bpt6k63756274.xml                n_total_snippets 687      n_good_snippets 0
# Joakim-Isa_1867_bpt6k6489017f.xml             n_total_snippets 2      n_good_snippets 0
# Joanne_1857_bpt6k64659860.xml                 n_total_snippets 35      n_good_snippets 0
# Kock_1842_bpt6k206782q.xml                    n_total_snippets 65      n_good_snippets 0
# Kock_1844_bpt6k15204573.xml                   n_total_snippets 66      n_good_snippets 0
# LaBédollière_1854_bpt6k6465635n.xml         n_total_snippets 42      n_good_snippets 0
# LaBédollière_1860_bpt6k1520574z.xml           n_total_snippets 2044      n_good_snippets 4
# LaGournerie_1854_bpt6k6394057f.xml            n_total_snippets 447      n_good_snippets 17
# LaPeyrière_1870_bpt6k6394041k.xml            n_total_snippets 117      n_good_snippets 2
# La_Rue_1867__bpt6k5458193t.xml                n_total_snippets 10      n_good_snippets 0
# Lacroix_1842_btv1b8530331q.xml                n_total_snippets 49      n_good_snippets 0
# Lahire_1848_bpt6k1265781q.xml                 n_total_snippets 15      n_good_snippets 0
# Lambert-Thiboust_1867_bpt6k14104565.xml       n_total_snippets 7      n_good_snippets 0
# Landremont_1848_bpt6k56646183.xml             n_total_snippets 80      n_good_snippets 0
# Langlois_1871_bpt6k5426891z.xml               n_total_snippets 5      n_good_snippets 0
# Lazare(2)_1870_bpt6k6465697r.xml              n_total_snippets 158      n_good_snippets 0
# Lazare_1870_bpt6k6489749t.xml                 n_total_snippets 65      n_good_snippets 0
# Lazare_1872_bpt6k6439523h.xml                 n_total_snippets 105      n_good_snippets 0
# LeHir_1855_bpt6k5828882k.xml                  n_total_snippets 48      n_good_snippets 0
# LeVerdier_1871_bpt6k6497565w.xml              n_total_snippets 36      n_good_snippets 0
# Lecour_1876_bpt6k6452320z.xml                 n_total_snippets 78      n_good_snippets 0
# Lecouturier_1848_bpt6k94648f.xml              n_total_snippets 7      n_good_snippets 0
# Lefeuve_1854_bpt6k6438988x.xml                n_total_snippets 52      n_good_snippets 0
# Lemer_1855_bpt6k64417126.xml                  n_total_snippets 61      n_good_snippets 0
# Lemoine_1844_bpt6k6474411h.xml                n_total_snippets 13      n_good_snippets 0
# Lespès_1863_bpt6k215326w.xml                  n_total_snippets 441      n_good_snippets 9
# Lespès_1863_bpt6k3044149h.xml                 n_total_snippets 40      n_good_snippets 0
# Leuret_1837_bpt6k12657090.xml                 n_total_snippets 3      n_good_snippets 0
# Lusson_1855_bpt6k58212578.xml                 n_total_snippets 7      n_good_snippets 0
# Malapert_1871_bpt6k54535994.xml               n_total_snippets 10      n_good_snippets 0
# Maleville_1865_bpt6k64488898.xml              n_total_snippets 198      n_good_snippets 4
# Martin-Rey_1870_bpt6k6356442w.xml             n_total_snippets 28      n_good_snippets 0
# Mémoires_dun_avocat_1847_bpt6k935404p.xml    n_total_snippets 46      n_good_snippets 0
# Mirecourt_1855_bpt6k317931z.xml               n_total_snippets 35      n_good_snippets 0
# Moisy_1855_bpt6k65397770.xml                  n_total_snippets 1      n_good_snippets 0
# Monnières_1838_bpt6k64397481.xml              n_total_snippets 475      n_good_snippets 0
# Montgravier_1858_bpt6k6480176v.xml            n_total_snippets 5      n_good_snippets 0
# Montépin_1868_bpt6k5790929r.xml               n_total_snippets 75      n_good_snippets 0
# Mornand_1855_bpt6k6396836n.xml                n_total_snippets 133      n_good_snippets 0
# Neuville_1867_bpt6k6439279v.xml               n_total_snippets 16      n_good_snippets 0
# Nodier_1836_bpt6k35054q.xml                   n_total_snippets 53      n_good_snippets 0
# Notice_sur_M_Thome_1877_bpt6k64705974.xml     n_total_snippets 4      n_good_snippets 0
# Ormoy_1849_bpt6k5852477v.xml                  n_total_snippets 123      n_good_snippets 0
# Palianti_1835_bpt6k5823750q.xml               n_total_snippets 7      n_good_snippets 0
# Paris-Commune_1871_bpt6k54973776.xml          n_total_snippets 143      n_good_snippets 0
# Paris-Partout_1868_bpt6k6441503j.xml          n_total_snippets 129      n_good_snippets 19
# Paris_Versailles_1871_bpt6k5452805s.xml       n_total_snippets 2      n_good_snippets 0
# Paris_au_dix-neuvième_1841_bpt6k110061v.xml   n_total_snippets 143      n_good_snippets 0
# Paris_à_la_main_1857_bpt6k353687.xml         n_total_snippets 41      n_good_snippets 0
# Paris_est-il_l'enfer_des_chevaux_1863_bpt6k1165923q.xml n_total_snippets 8      n_good_snippets 0
# Paris_et_Rome_1876_bpt6k5471690p.xml          n_total_snippets 3      n_good_snippets 0
# Paris_et_environs_1855_bpt6k6378614f.xml      n_total_snippets 373      n_good_snippets 22
# Paris_moderne_1837_bpt6k5545103f.xml          n_total_snippets 27      n_good_snippets 0
# Paris_passé_1877_bpt6k54689392.xml           n_total_snippets 4      n_good_snippets 0
# Paris_sous_la_Commune_1871_bpt6k58375316.xml  n_total_snippets 22      n_good_snippets 0
# Petits_mystères_1846_bpt6k164368r.xml         n_total_snippets 15      n_good_snippets 0
# Physiologie_des_cafes_1841_bpt6k6439512q.xml  n_total_snippets 19      n_good_snippets 0
# Picot_1870_bpt6k54426475.xml                  n_total_snippets 1      n_good_snippets 0
# Ponson_1863_bpt6k11719601.xml                 n_total_snippets 17      n_good_snippets 0
# Promenade_artistique_1838_bpt6k6378049k.xml   n_total_snippets 62      n_good_snippets 5
# Prévost_1833_bpt6k58147990.xml                n_total_snippets 7      n_good_snippets 0
# Pène_1861_bpt6k6438637k.xml                   n_total_snippets 81      n_good_snippets 0
# Pène_1863_bpt6k6439251s.xml                   n_total_snippets 81      n_good_snippets 0
# Pène_1864_bpt6k6438378g.xml                   n_total_snippets 88      n_good_snippets 0
# Pélin_1861_bpt6k6417129f.xml                  n_total_snippets 18      n_good_snippets 0
# Pélin_1861_bpt6k64416865.xml                  n_total_snippets 6      n_good_snippets 0
# Rambuteau_1836_bpt6k6376107z.xml              n_total_snippets 130      n_good_snippets 0
# Relation_officielle_1831_bpt6k55267943.xml    n_total_snippets 17      n_good_snippets 0
# Renard_1841_bpt6k63910867.xml                 n_total_snippets 35      n_good_snippets 0
# Riga_1857_bpt6k64950288.xml                   n_total_snippets 90      n_good_snippets 0
# Robville_1869_bpt6k1166666r.xml               n_total_snippets 19      n_good_snippets 0
# Rolland_1833_bpt6k6490754m.xml                n_total_snippets 3      n_good_snippets 0
# Rousseau_1861_bpt6k54052147.xml               n_total_snippets 25      n_good_snippets 0
# Rouvières_1830_bpt6k74308z.xml                n_total_snippets 26      n_good_snippets 2
# Roze_1853_bpt6k5551419c.xml                   n_total_snippets 75      n_good_snippets 0
# Saint-Georges_1845_bpt6k9792691h.xml          n_total_snippets 2      n_good_snippets 0
# Salvador_1844_bpt6k5780059h.xml               n_total_snippets 171      n_good_snippets 0
# Sardou_1866_bpt6k6522033z.xml                 n_total_snippets 9      n_good_snippets 0
# Saunier_1871_bpt6k5448694p.xml                n_total_snippets 1      n_good_snippets 0
# Seyval_1846_bpt6k64725399.xml                 n_total_snippets 1      n_good_snippets 0
# Sénard_1850_bpt6k6213115p.xml                n_total_snippets 70      n_good_snippets 0
# Silvestre_1853_bpt6k6416931z.xml              n_total_snippets 22      n_good_snippets 0
# Soullier_1861_bpt6k6374814w.xml               n_total_snippets 76      n_good_snippets 0
# Stadt_1871_bpt6k5452947g.xml                  n_total_snippets 3      n_good_snippets 0
# Tableau_universel_1833_bpt6k63954418.xml      n_total_snippets 398      n_good_snippets 0
# Tanski_1869_bpt6k6366019j.xml                 n_total_snippets 6      n_good_snippets 0
# Tissot_1830_bpt6k6464072j.xml                 n_total_snippets 34      n_good_snippets 0
# Troche_1837_bpt6k58469052.xml                 n_total_snippets 28      n_good_snippets 0
# TurpindeCrissé_1835_bpt6k9765736r.xml        n_total_snippets 87      n_good_snippets 0
# Ulbach_1871_bpt6k5802400x.xml                 n_total_snippets 59      n_good_snippets 0
# Van_Tenac_1845_bpt6k6447540p.xml              n_total_snippets 271      n_good_snippets 6
# Vidocq_1830_bpt6k1050540s.xml                 n_total_snippets 17      n_good_snippets 0
# Villemessant_1860_vol1_bpt6k30443585.xml      n_total_snippets 30      n_good_snippets 0
# Villemessant_1860_vol2_bpt6k3044359k.xml      n_total_snippets 23      n_good_snippets 0
# Virmaître_1871_bpt6k5448441v.xml             n_total_snippets 123      n_good_snippets 0
# Virmaître_1868_bpt6k6436639s.xml              n_total_snippets 64      n_good_snippets 0
# Véron_1866_bpt6k6481597q.xml                  n_total_snippets 81      n_good_snippets 0
# Watripon_1861_bpt6k64640677.xml               n_total_snippets 2      n_good_snippets 0
# Wendel_1845_bpt6k58122757.xml                 n_total_snippets 1      n_good_snippets 0
# Witt_1864_bpt6k58444791.xml                   n_total_snippets 10      n_good_snippets 0
#
# grand_total_snippets 18673     grand_total_good_snippets 583
